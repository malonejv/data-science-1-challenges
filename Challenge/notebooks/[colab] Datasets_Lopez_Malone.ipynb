# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive

# %%
import pandas as pd

# %% [markdown]
# # Elección de Datasets - Datasets pontenciales
#
# **Alumno**: Javier López Malone
#
# **Profesora**: Estefania Karina Susanj
#
# **Tutor**: Rubén Baquel
#
# ## Dataset 1: LinkedIn Job Postings 2023
#
# Fuente: [LinkedIn Job Postings - 2023 | Kaggle](https://www.kaggle.com/datasets/arshkon/linkedin-job-postings)

# %%
linkedin_posting_dataframe = pd.read_csv('/content/gdrive/MyDrive/Cursos/DataScienceI_Challenge/datasets/1. linkedin_job_postings_2023/job_postings.csv')

# %%
linkedin_posting_dataframe.shape
# Out:
# (33246, 28)

# %%
linkedin_posting_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33245 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  13352 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  float64
#  12  remote_allowed              4802 non-null   float64
# ...

# %%
# No utilizo linkedin_posting_dataframe.head() porque me hace un truncate de varias columnas
linkedin_posting_dataframe.iloc[:5,:14]
# Out:
#        job_id  company_id                                              title  \
# 0  3757940104    553718.0                              Hearing Care Provider
# 1  3757940025   2192142.0  Shipping & Receiving Associate 2nd shift (Beav...
# 2  3757938019    474443.0                               Manager, Engineering
# 3  3757938018  18213359.0                                               Cook
# 4  3757937095    437225.0        Principal Cloud Security Architect (Remote)
#
#                                          description  max_salary  med_salary  \
# 0  Overview\n\nHearingLife is a national hearing ...         NaN     5250.00
# 1  Metalcraft of Mayville\nMetalcraft of Mayville...         NaN         NaN
# 2  \nThe TSUBAKI name is synonymous with excellen...         NaN         NaN
# 3  descriptionTitle\n\n Looking for a great oppor...         NaN       22.27
# 4  Job Summary\nAt iHerb, we are on a mission to ...    275834.0         NaN
#
# ...

# %%
linkedin_posting_dataframe.iloc[:5,15:]
# Out:
#                                      application_url application_type  \
# 0  https://careers-demant.icims.com/jobs/19601/he...     OffsiteApply
# 1  https://www.click2apply.net/mXLQz5S5NEYEXsKjwH...     OffsiteApply
# 2  https://www.click2apply.net/LwbOykH2yAJdahB5Ah...     OffsiteApply
# 3  https://jobs.apploi.com/view/854782?utm_campai...     OffsiteApply
# 4  https://careers.iherb.com/global/en/job/IHINGL...     OffsiteApply
#
#          expiry  closed_time formatted_experience_level  \
# 0  1.701680e+12          NaN                Entry level
# 1  1.701680e+12          NaN                        NaN
# 2  1.701680e+12          NaN                        NaN
# 3  1.701680e+12          NaN                Entry level
# 4  1.701680e+12          NaN           Mid-Senior level
#
#                                          skills_desc   listed_time  \
# 0                                                NaN  1.699090e+12
# 1                                                NaN  1.699080e+12
# ...

# %%
linkedin_posting_dataframe.describe()
# Out:
#              job_id    company_id    max_salary     med_salary     min_salary  \
# count  3.324600e+04  3.259200e+04  1.111100e+04    2241.000000   11111.000000
# mean   3.723675e+09  1.145638e+07  8.880883e+04   32426.170598   62650.128421
# std    9.264310e+07  2.391219e+07  8.764506e+04   76860.422528   58732.644143
# min    3.958427e+06  1.009000e+03  1.000000e+01       0.000000       7.250000
# 25%    3.697367e+09  1.840100e+04  5.100000e+01      18.780000      40.945000
# 50%    3.749345e+09  4.687820e+05  8.392800e+04      29.000000   62128.000000
# 75%    3.756905e+09  9.222480e+06  1.400000e+05   42746.000000  100000.000000
# max    3.757940e+09  1.011741e+08  1.300000e+06  998426.000000  800000.000000
#
#             applies  original_listed_time  remote_allowed         views  \
# count  16238.000000          3.324600e+04          4802.0  25886.000000
# mean      18.895246          1.695907e+12             1.0     58.339875
# ...

# %% [markdown]
# Observaciones:
# Algunas variables potencialmente interesantes podrían ser:
#
# **Salario (max_salary) (med_salary) (min_salary)**: Las columnas max_salary, med_salary y min_salary pueden ser importantes para el análisis salarial. Sin embargo tienen una cantidad considerable de datos nulos, pero podrían ser útiles para analizar la distribución salarial y las tendencias en el mercado laboral.
#
# **Ubicación (location)**: La columna location puede ayudar a entender las diferencias regionales en términos de oferta laboral y salarios. Podría ser útil para analizar qué áreas tienen más oportunidades de trabajo.
#
# **Visitas (views)**: La columna views se podría utilizar como una medida de la popularidad de la oferta de trabajo. Podría ser útil para identificar qué trabajos atraen más atención, aunque también hay que considerar la cantidad de datos nulos.

# %% [markdown]
# ## Dataset 2: Spotify Tracks Dataset
#
# Fuente: [Spotify Tracks Dataset | Kaggle](https://www.kaggle.com/datasets/maharshipandya/-spotify-tracks-dataset)
#
# Es un conjunto de datos de pistas de Spotify en una variedad de 125 géneros diferentes.

# %%
spotify_dataframe= pd.read_csv('/content/gdrive/MyDrive/Cursos/DataScienceI_Challenge/datasets/2. spotify_tracks/dataset.csv')

# %%
spotify_dataframe.shape
# Out:
# (114000, 21)

# %%
spotify_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
spotify_dataframe.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
spotify_dataframe.describe()
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %% [markdown]
# Observaciones:
#
# **Popularidad de la pista (popularity)**: Puede ser interesante para analizar cómo se distribuye la popularidad entre diferentes géneros musicales, o por artistas.
#
# **Duración de la pista (duration_ms)**: Podría utilizarse para analizar si existe una relación entre la duración de la pista y diferentes géneros musicales.
#
# **Bailabilidad (danceability), energía (energy), vivacidad (liveness), valencia (valence)**: Con estas características se podría obtener información sobre estilos y atmósfera de una pista. Se podrían comparar estas características entre diferentes géneros musicales.

# %% [markdown]
# ## Dataset 3: Fake/real postings
#
# Fuente: [Real / Fake Job Posting Prediction | Kaggle](https://www.kaggle.com/datasets/shivamb/real-or-fake-fake-jobposting-prediction)
#
# Este conjunto de datos contiene 18.000 descripciones de puestos de trabajo, de las cuales unas 800 son falsas. Los datos constan tanto de información textual como de metainformación sobre los puestos de trabajo. El conjunto de datos se puede utilizar para crear modelos de clasificación que puedan conocer las descripciones de puestos que son fraudulentas.

# %%
fake_real_posting_dataframe= pd.read_csv('/content/gdrive/MyDrive/Cursos/DataScienceI_Challenge/datasets/3. real_fake_job_posting_prediction/fake_job_postings.csv')

# %%
fake_real_posting_dataframe.shape
# Out:
# (17880, 18)

# %%
fake_real_posting_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               17880 non-null  int64
#  1   title                17880 non-null  object
#  2   location             17534 non-null  object
#  3   department           6333 non-null   object
#  4   salary_range         2868 non-null   object
#  5   company_profile      14572 non-null  object
#  6   description          17879 non-null  object
#  7   requirements         15185 non-null  object
#  8   benefits             10670 non-null  object
#  9   telecommuting        17880 non-null  int64
#  10  has_company_logo     17880 non-null  int64
#  11  has_questions        17880 non-null  int64
#  12  employment_type      14409 non-null  object
#  13  required_experience  10830 non-null  object
#  14  required_education   9775 non-null   object
# ...

# %%
fake_real_posting_dataframe.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
# 3      Sales          NaN  Our passion for improving quality of life thro...
# 4        NaN          NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# ...

# %%
fake_real_posting_dataframe.describe()
# Out:
#              job_id  telecommuting  has_company_logo  has_questions  \
# count  17880.000000   17880.000000      17880.000000   17880.000000
# mean    8940.500000       0.042897          0.795302       0.491723
# std     5161.655742       0.202631          0.403492       0.499945
# min        1.000000       0.000000          0.000000       0.000000
# 25%     4470.750000       0.000000          1.000000       0.000000
# 50%     8940.500000       0.000000          1.000000       0.000000
# 75%    13410.250000       0.000000          1.000000       1.000000
# max    17880.000000       1.000000          1.000000       1.000000
#
#          fraudulent
# count  17880.000000
# mean       0.048434
# std        0.214688
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
valid=fake_real_posting_dataframe[fake_real_posting_dataframe.fraudulent==0].fraudulent.count()
fraudulents=fake_real_posting_dataframe[fake_real_posting_dataframe.fraudulent==1].fraudulent.count()

print(f"Valid Job Posting: {valid} | Fraudulent Job Posting: {fraudulents}")
# Out:
# Valid Job Posting: 17014 | Fraudulent Job Posting: 866

# %% [markdown]
# Observaciones:
#
# **Rango salarial (salary_range)**: A pesar de la cantidad de datos nulos, podría ser útil para analizar la distribución salarial de los trabajos por país o ciudad.
#
# **Fraudulento (fraudulent)**: Con esta variable podría ser útil para investigar prácticas fraudulentas en las plataformas de empleo.
